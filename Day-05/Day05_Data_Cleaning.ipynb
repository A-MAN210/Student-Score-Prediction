# %%
import numpy as np
import pandas as pd

# %%
#Loading the Dataset file.
df = pd.read_csv("student_scores.csv")

# %%
df
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0            1          1.0                     60          5.0
# 1            2          1.5                     62          5.5
# 2            3          2.0                     65          6.0
# 3            4          2.5                     68          6.0
# 4            5          3.0                     70          6.5
# 5            6          3.5                     72          7.0
# 6            7          4.0                     75          7.0
# 7            8          4.5                     78          7.5
# 8            9          5.0                     80          7.5
# 9           10          5.5                     82          8.0
# 10          11          6.0                     85          8.0
# 11          12          6.5                     86          8.0
# 12          13          7.0                     88          8.5
# 13          14          7.5                     90          8.5
# ...

# %%
df.shape
# Out:
# (20, 6)

# %%
# It shows the first 5 rows.
df.head()
# Out:
#    Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0           1          1.0                     60          5.0
# 1           2          1.5                     62          5.5
# 2           3          2.0                     65          6.0
# 3           4          2.5                     68          6.0
# 4           5          3.0                     70          6.5
#
#    Previous_Score  Score
# 0               8   10.0
# 1              12   16.0
# 2              18   21.0
# 3              22   26.0
# 4              28   32.0

# %%
# Checking all the null values.
#True means it has Null value.
df.isna()
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0        False        False                  False        False
# 1        False        False                  False        False
# 2        False        False                  False        False
# 3        False        False                  False        False
# 4        False        False                  False        False
# 5        False        False                  False        False
# 6        False        False                  False        False
# 7        False        False                  False        False
# 8        False        False                  False        False
# 9        False        False                  False        False
# 10       False        False                  False        False
# 11       False        False                  False        False
# 12       False        False                  False        False
# 13       False        False                  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Study_Hours              0
# Attendance_Percentage    0
# Sleep_Hours              0
# Previous_Score           0
# Score                    2
# dtype: int64

# %%
df.loc[2,'Score']
# Out:
# np.float64(21.0)

# %%
#If null value is filled by mean.
#Method-1
df['Score'] = df['Score'].fillna(df['Score'].mean())

# %%
df
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0            1          1.0                     60          5.0
# 1            2          1.5                     62          5.5
# 2            3          2.0                     65          6.0
# 3            4          2.5                     68          6.0
# 4            5          3.0                     70          6.5
# 5            6          3.5                     72          7.0
# 6            7          4.0                     75          7.0
# 7            8          4.5                     78          7.5
# 8            9          5.0                     80          7.5
# 9           10          5.5                     82          8.0
# 10          11          6.0                     85          8.0
# 11          12          6.5                     86          8.0
# 12          13          7.0                     88          8.5
# 13          14          7.5                     90          8.5
# ...

# %%
#Method-2
df.fillna(df.mean(numeric_only=True))
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0            1          1.0                     60          5.0
# 1            2          1.5                     62          5.5
# 2            3          2.0                     65          6.0
# 3            4          2.5                     68          6.0
# 4            5          3.0                     70          6.5
# 5            6          3.5                     72          7.0
# 6            7          4.0                     75          7.0
# 7            8          4.5                     78          7.5
# 8            9          5.0                     80          7.5
# 9           10          5.5                     82          8.0
# 10          11          6.0                     85          8.0
# 11          12          6.5                     86          8.0
# 12          13          7.0                     88          8.5
# 13          14          7.5                     90          8.5
# ...

# %%
# Null value ki rows drop ho jaayegi.
df.dropna()
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0            1          1.0                     60          5.0
# 1            2          1.5                     62          5.5
# 2            3          2.0                     65          6.0
# 3            4          2.5                     68          6.0
# 4            5          3.0                     70          6.5
# 5            6          3.5                     72          7.0
# 6            7          4.0                     75          7.0
# 7            8          4.5                     78          7.5
# 8            9          5.0                     80          7.5
# 9           10          5.5                     82          8.0
# 10          11          6.0                     85          8.0
# 11          12          6.5                     86          8.0
# 12          13          7.0                     88          8.5
# 13          14          7.5                     90          8.5
# ...

# %%
# To count exact duplicate rows.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# count    20.00000    20.000000              20.000000    20.000000
# mean     10.50000     5.075000              79.150000     7.450000
# std       5.91608     2.627161              11.590718     1.296757
# min       1.00000     1.000000              60.000000     5.000000
# 25%       5.75000     2.875000              69.500000     6.375000
# 50%      10.50000     5.000000              80.000000     7.500000
# 75%      15.25000     7.125000              88.500000     8.500000
# max      20.00000     9.500000              97.000000     9.500000
#
#        Previous_Score      Score
# count       20.000000  20.000000
# mean        49.300000  51.222222
# std         26.885919  26.110203
# min          8.000000  10.000000
# 25%         26.500000  30.500000
# 50%         49.000000  51.222222
# 75%         71.000000  70.500000
# max         93.000000  97.000000

# %%
df['Score'].median()
# Out:
# 51.22222222222222

# %%
df['Study_Hours'].std()
# Out:
# 2.627160764820175

# %%
df['Score'] = df['Score'].astype(float)
df
# Out:
#     Student_ID  Study_Hours  Attendance_Percentage  Sleep_Hours  \
# 0            1          1.0                     60          5.0
# 1            2          1.5                     62          5.5
# 2            3          2.0                     65          6.0
# 3            4          2.5                     68          6.0
# 4            5          3.0                     70          6.5
# 5            6          3.5                     72          7.0
# 6            7          4.0                     75          7.0
# 7            8          4.5                     78          7.5
# 8            9          5.0                     80          7.5
# 9           10          5.5                     82          8.0
# 10          11          6.0                     85          8.0
# 11          12          6.5                     86          8.0
# 12          13          7.0                     88          8.5
# 13          14          7.5                     90          8.5
# ...

# %%
# Saving the cleaned version:
df.to_csv("student_scores_cleaned.csv", index=False)
